# %%
import time
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy.spatial import distance_matrix

# %%
filename = "eil51_json_array.txt"
exec(open("mst_dfs_hamiltonian_script_final.py").read())
# Out:
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.005987882614135742  seconds
# Total distance is :  645

# %%
print(opt_route)
print(duration)
print(total_distance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-776114ab2bdc> in <module>()
# ----> 1 print(opt_route)
#       2 print(duration)
#       3 print(total_distance)
#
# NameError: name 'opt_route' is not defined

# %%
import glob
data_set_name_list = glob.glob("./*.txt")
for i in range(len(data_set_name_list)):
    data_set_name_list[i] = data_set_name_list[i].replace(".\\","")
data_set_name_list[5]
# Out:
# 'd1291_json_array.txt'

# %%
name_list = []
route_list = []
duration_list = []
total_distance_list = []
for i in data_set_name_list:
    filename = i
    exec(open("mst_dfs_hamiltonian_script_final.py").read())
    name_list.append(filename)
    route_list.append(opt_route)
    duration_list.append(duration)
    total_distance_list.append(total_distance)
    print("Data set is done: ",filename)
# Out:
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.05938863754272461  seconds
# Total distance is :  3721
# Data set is done:  a280_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.006490945816040039  seconds
# Total distance is :  10548
# Data set is done:  berlin52_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.01746654510498047  seconds
# Total distance is :  155906
# Data set is done:  bier127_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.017467498779296875  seconds
# Total distance is :  8387
# Data set is done:  ch130_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.020960330963134766  seconds
# Total distance is :  9446
# Data set is done:  ch150_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.8429319858551025  seconds
# Total distance is :  74971
# Data set is done:  d1291_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  1.4468119144439697  seconds
# Total distance is :  85323
# Data set is done:  d1655_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.03697848320007324  seconds
# Total distance is :  19568
# Data set is done:  d198_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  2.3111979961395264  seconds
# Total distance is :  125702
# Data set is done:  d2103_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.15769195556640625  seconds
# Total distance is :  46284
# Data set is done:  d493_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.24254775047302246  seconds
# Total distance is :  66437
# Data set is done:  d657_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.012977361679077148  seconds
# Total distance is :  916
# Data set is done:  eil101_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.005500316619873047  seconds
# Total distance is :  645
# Data set is done:  eil51_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.008983135223388672  seconds
# Total distance is :  775
# Data set is done:  eil76_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  1.066032886505127  seconds
# Total distance is :  29902
# Data set is done:  fl1400_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  1.2846245765686035  seconds
# Total distance is :  31414
# Data set is done:  fl1577_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  7.241537809371948  seconds
# Total distance is :  42317
# Data set is done:  fl3785_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.16318440437316895  seconds
# Total distance is :  16405
# Data set is done:  fl417_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  9.838671922683716  seconds
# Total distance is :  251488
# Data set is done:  fnl4461_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.11876463890075684  seconds
# Total distance is :  3540
# Data set is done:  gil262_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.012475967407226562  seconds
# Total distance is :  30035
# Data set is done:  kroA100_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.02095961570739746  seconds
# Total distance is :  36699
# Data set is done:  kroA150_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.03144097328186035  seconds
# Total distance is :  41078
# Data set is done:  kroA200_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.01197671890258789  seconds
# Total distance is :  27677
# Data set is done:  kroB100_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.02096104621887207  seconds
# Total distance is :  35962
# Data set is done:  kroB150_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.03145647048950195  seconds
# Total distance is :  40255
# Data set is done:  kroB200_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.012970209121704102  seconds
# Total distance is :  28623
# Data set is done:  kroC100_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.012476921081542969  seconds
# Total distance is :  28598
# Data set is done:  kroD100_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.01247715950012207  seconds
# Total distance is :  30159
# Data set is done:  kroE100_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.01347494125366211  seconds
# Total distance is :  21433
# Data set is done:  lin105_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.06837296485900879  seconds
# Total distance is :  61367
# Data set is done:  lin318_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.9696948528289795  seconds
# Total distance is :  77970
# Data set is done:  nrw1379_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.24655461311340332  seconds
# Total distance is :  47871
# Data set is done:  p654_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.6991961002349854  seconds
# Total distance is :  83046
# Data set is done:  pcb1173_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  4.5585150718688965  seconds
# Total distance is :  197996
# Data set is done:  pcb3038_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.14977812767028809  seconds
# Total distance is :  72538
# Data set is done:  pcb442_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.5370161533355713  seconds
# Total distance is :  353590
# Data set is done:  pr1002_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.014473199844360352  seconds
# Total distance is :  55882
# Data set is done:  pr107_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.016469240188598633  seconds
# Total distance is :  77604
# Data set is done:  pr124_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.018465042114257812  seconds
# Total distance is :  146004
# Data set is done:  pr136_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.01996326446533203  seconds
# Total distance is :  77787
# Data set is done:  pr144_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.02195906639099121  seconds
# Total distance is :  92056
# Data set is done:  pr152_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.040464162826538086  seconds
# Total distance is :  115120
# Data set is done:  pr226_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  2.810270071029663  seconds
# Total distance is :  529920
# Data set is done:  pr2392_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.06388092041015625  seconds
# Total distance is :  69625
# Data set is done:  pr264_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.06038975715637207  seconds
# Total distance is :  66650
# Data set is done:  pr299_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.12175655364990234  seconds
# Total distance is :  143627
# Data set is done:  pr439_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.008983850479125977  seconds
# Total distance is :  148461
# Data set is done:  pr76_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.031455278396606445  seconds
# Total distance is :  3399
# Data set is done:  rat195_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.18964672088623047  seconds
# Total distance is :  9646
# Data set is done:  rat575_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.3318963050842285  seconds
# Total distance is :  12612
# Data set is done:  rat783_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.012476444244384766  seconds
# Total distance is :  1747
# Data set is done:  rat99_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.011977195739746094  seconds
# Total distance is :  10900
# Data set is done:  rd100_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.10030746459960938  seconds
# Total distance is :  21204
# Data set is done:  rd400_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  71.83534479141235  seconds
# Total distance is :  1387125
# Data set is done:  rl11849_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  1.0809922218322754  seconds
# Total distance is :  359826
# Data set is done:  rl1304_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.8993263244628906  seconds
# Total distance is :  391210
# Data set is done:  rl1323_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  1.8181328773498535  seconds
# Total distance is :  448293
# Data set is done:  rl1889_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  17.11516046524048  seconds
# Total distance is :  855923
# Data set is done:  rl5915_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  17.83082914352417  seconds
# Total distance is :  836104
# Data set is done:  rl5934_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.08234095573425293  seconds
# Total distance is :  186740
# Data set is done:  ts225_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.03792929649353027  seconds
# Total distance is :  5546
# Data set is done:  tsp225_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.5844113826751709  seconds
# Total distance is :  304448
# Data set is done:  u1060_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  1.0221569538116455  seconds
# Total distance is :  215709
# Data set is done:  u1432_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.02347087860107422  seconds
# Total distance is :  54617
# Data set is done:  u159_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  1.6684093475341797  seconds
# Total distance is :  83145
# Data set is done:  u1817_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  2.3576149940490723  seconds
# Total distance is :  95810
# Data set is done:  u2152_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  2.681523561477661  seconds
# Total distance is :  322426
# Data set is done:  u2319_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.1912071704864502  seconds
# Total distance is :  48107
# Data set is done:  u574_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  0.2870209217071533  seconds
# Total distance is :  60103
# Data set is done:  u724_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  90.69671154022217  seconds
# Total distance is :  27648864
# Data set is done:  usa13509_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  1.0924513339996338  seconds
# Total distance is :  341020
# Data set is done:  vm1084_json_array.txt
# Edge 	Weight
# Following is DFS from (starting from vertex 5)
# Total execution time is:  1.5975260734558105  seconds
# Total distance is :  460900
# Data set is done:  vm1748_json_array.txt

# %%
# ALL 73 datasets optimum solutions respect to Heidelberg TSP 
# Datasets sorted Alphabetical like. a280  berlin52  bier127  ch130     etc....

optimum_solution_list = [2579,7542,118282,6110,6528,50801,62128,15780,80450,35002,48912,629,426,
538,20127,22249,28772,11861,182566,2378,21282,26524,29368,22141,26130,29437,20749,21294,22068,
14379,42029,56638,34643,56892,137694,50778,259045,44303,59030,96772,58537,73682,80369,378032,
49135,48191,107217,108159,2323,6773,8806,1211,7910,15281,923288,252948,270199,316536,565530,
556045,126643,3916,224094,152970,42080,57201,64253,234256,36905,41910,19982859,239297,336556 ]
len(optimum_solution_list)
# Out:
# 73

# %%
name_list = sorted(name_list)

# %%
name_list
# Out:
# ['a280_json_array.txt',
#  'berlin52_json_array.txt',
#  'bier127_json_array.txt',
#  'ch130_json_array.txt',
#  'ch150_json_array.txt',
#  'd1291_json_array.txt',
#  'd1655_json_array.txt',
#  'd198_json_array.txt',
#  'd2103_json_array.txt',
#  'd493_json_array.txt',
#  'd657_json_array.txt',
#  'eil101_json_array.txt',
#  'eil51_json_array.txt',
#  'eil76_json_array.txt',
#  'fl1400_json_array.txt',
#  'fl1577_json_array.txt',
#  'fl3785_json_array.txt',
#  'fl417_json_array.txt',
#  'fnl4461_json_array.txt',
#  'gil262_json_array.txt',
#  'kroA100_json_array.txt',
#  'kroA150_json_array.txt',
#  'kroA200_json_array.txt',
#  'kroB100_json_array.txt',
#  'kroB150_json_array.txt',
#  'kroB200_json_array.txt',
#  'kroC100_json_array.txt',
#  'kroD100_json_array.txt',
#  'kroE100_json_array.txt',
#  'lin105_json_array.txt',
#  'lin318_json_array.txt',
#  'nrw1379_json_array.txt',
#  'p654_json_array.txt',
#  'pcb1173_json_array.txt',
#  'pcb3038_json_array.txt',
#  'pcb442_json_array.txt',
#  'pr1002_json_array.txt',
#  'pr107_json_array.txt',
#  'pr124_json_array.txt',
#  'pr136_json_array.txt',
#  'pr144_json_array.txt',
#  'pr152_json_array.txt',
#  'pr226_json_array.txt',
#  'pr2392_json_array.txt',
#  'pr264_json_array.txt',
#  'pr299_json_array.txt',
#  'pr439_json_array.txt',
#  'pr76_json_array.txt',
#  'rat195_json_array.txt',
#  'rat575_json_array.txt',
#  'rat783_json_array.txt',
#  'rat99_json_array.txt',
#  'rd100_json_array.txt',
#  'rd400_json_array.txt',
#  'rl11849_json_array.txt',
#  'rl1304_json_array.txt',
#  'rl1323_json_array.txt',
#  'rl1889_json_array.txt',
#  'rl5915_json_array.txt',
#  'rl5934_json_array.txt',
#  'ts225_json_array.txt',
#  'tsp225_json_array.txt',
#  'u1060_json_array.txt',
#  'u1432_json_array.txt',
#  'u159_json_array.txt',
#  'u1817_json_array.txt',
#  'u2152_json_array.txt',
#  'u2319_json_array.txt',
#  'u574_json_array.txt',
#  'u724_json_array.txt',
#  'usa13509_json_array.txt',
#  'vm1084_json_array.txt',
#  'vm1748_json_array.txt']

# %%
number_of_cities = []
for i in route_list:
    number_of_cities.append(len(i))

# %%
number_of_cities[:5]
# Out:
# [280, 52, 127, 130, 150]

# %%
result_table = {'Dataset Name':name_list,
                'Number of Cities':number_of_cities,
                'Optimum Distance':optimum_solution_list,
                'MST Distance':total_distance_list,
                'Execution Time (Seconds)':duration_list}

# %%
result_df = pd.DataFrame(data=result_table)
result_df['Percentage Error'] = np.nan
for i in range(len(name_list)):
    result_df['Percentage Error'][i] = (1 - (result_df['Optimum Distance'][i]/result_df['MST Distance'][i]))*100
# Out:
# C:\Users\orhan\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
fabian_df = result_df[['Dataset Name','Execution Time (Seconds)','MST Distance']]

# %%
fabian_df
# Out:
#                Dataset Name  Execution Time (Seconds)  MST Distance
# 0       a280_json_array.txt                  0.059389          3721
# 1   berlin52_json_array.txt                  0.006491         10548
# 2    bier127_json_array.txt                  0.017467        155906
# 3      ch130_json_array.txt                  0.017467          8387
# 4      ch150_json_array.txt                  0.020960          9446
# 5      d1291_json_array.txt                  0.842932         74971
# 6      d1655_json_array.txt                  1.446812         85323
# 7       d198_json_array.txt                  0.036978         19568
# 8      d2103_json_array.txt                  2.311198        125702
# 9       d493_json_array.txt                  0.157692         46284
# 10      d657_json_array.txt                  0.242548         66437
# 11    eil101_json_array.txt                  0.012977           916
# 12     eil51_json_array.txt                  0.005500           645
# 13     eil76_json_array.txt                  0.008983           775
# 14    fl1400_json_array.txt                  1.066033         29902
# 15    fl1577_json_array.txt                  1.284625         31414
# 16    fl3785_json_array.txt                  7.241538         42317
# 17     fl417_json_array.txt                  0.163184         16405
# 18   fnl4461_json_array.txt                  9.838672        251488
# 19    gil262_json_array.txt                  0.118765          3540
# 20   kroA100_json_array.txt                  0.012476         30035
# 21   kroA150_json_array.txt                  0.020960         36699
# 22   kroA200_json_array.txt                  0.031441         41078
# 23   kroB100_json_array.txt                  0.011977         27677
# 24   kroB150_json_array.txt                  0.020961         35962
# 25   kroB200_json_array.txt                  0.031456         40255
# 26   kroC100_json_array.txt                  0.012970         28623
# 27   kroD100_json_array.txt                  0.012477         28598
# 28   kroE100_json_array.txt                  0.012477         30159
# 29    lin105_json_array.txt                  0.013475         21433
# ..                      ...                       ...           ...
# 43    pr2392_json_array.txt                  2.810270        529920
# 44     pr264_json_array.txt                  0.063881         69625
# 45     pr299_json_array.txt                  0.060390         66650
# 46     pr439_json_array.txt                  0.121757        143627
# 47      pr76_json_array.txt                  0.008984        148461
# 48    rat195_json_array.txt                  0.031455          3399
# 49    rat575_json_array.txt                  0.189647          9646
# 50    rat783_json_array.txt                  0.331896         12612
# 51     rat99_json_array.txt                  0.012476          1747
# 52     rd100_json_array.txt                  0.011977         10900
# 53     rd400_json_array.txt                  0.100307         21204
# 54   rl11849_json_array.txt                 71.835345       1387125
# 55    rl1304_json_array.txt                  1.080992        359826
# 56    rl1323_json_array.txt                  0.899326        391210
# 57    rl1889_json_array.txt                  1.818133        448293
# 58    rl5915_json_array.txt                 17.115160        855923
# 59    rl5934_json_array.txt                 17.830829        836104
# 60     ts225_json_array.txt                  0.082341        186740
# 61    tsp225_json_array.txt                  0.037929          5546
# 62     u1060_json_array.txt                  0.584411        304448
# 63     u1432_json_array.txt                  1.022157        215709
# 64      u159_json_array.txt                  0.023471         54617
# 65     u1817_json_array.txt                  1.668409         83145
# 66     u2152_json_array.txt                  2.357615         95810
# 67     u2319_json_array.txt                  2.681524        322426
# 68      u574_json_array.txt                  0.191207         48107
# 69      u724_json_array.txt                  0.287021         60103
# 70  usa13509_json_array.txt                 90.696712      27648864
# 71    vm1084_json_array.txt                  1.092451        341020
# 72    vm1748_json_array.txt                  1.597526        460900
#
# [73 rows x 3 columns]

# %%
fabian_df.to_csv("./minimum_spanning_tree_results.csv",index=False)

# %%
result_df.to_excel("./minimum_spanning_tree_all.xlsx", index=False)
